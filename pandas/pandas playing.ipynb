# %%
import pandas as pd
import numpy as np

# %%
data = [1,2.3,4,1,6,7]

# %%
pd.Series(data)
# Out:
# 0    1.0
# 1    2.3
# 2    4.0
# 3    1.0
# 4    6.0
# 5    7.0
# dtype: float64

# %%
pd.Series(data, index=['a','b','c','d','e','f'])
# Out:
# a    1.0
# b    2.3
# c    4.0
# d    1.0
# e    6.0
# f    7.0
# dtype: float64

# %%
pd.DataFrame(data)
# Out:
#      0
# 0  1.0
# 1  2.3
# 2  4.0
# 3  1.0
# 4  6.0
# 5  7.0

# %%
columns = ['Gabe','Tex','Jimbo','Kaylee','Seth','Jonah']

# %%
data_names = np.array(data)

# %%
pd.DataFrame(data_names.reshape(-1,len(data)), columns = columns)
# Out:
#    Gabe  Tex  Jimbo  Kaylee  Seth  Jonah
# 0   1.0  2.3    4.0     1.0   6.0    7.0

# %%
data2 = {'Ohio':17000,'Massachusetts':3200,'California':12500, 'Texas':12003}

# %%
pd.Series(data2)
# Out:
# Ohio             17000
# Massachusetts     3200
# California       12500
# Texas            12003
# dtype: int64

# %%
pd.DataFrame(data2, index=[1,2,3,4])
# Out:
#     Ohio  Massachusetts  California  Texas
# 1  17000           3200       12500  12003
# 2  17000           3200       12500  12003
# 3  17000           3200       12500  12003
# 4  17000           3200       12500  12003

# %%
pd.DataFrame(data2, index=[0])
# Out:
#     Ohio  Massachusetts  California  Texas
# 0  17000           3200       12500  12003

# %%
pd.DataFrame(data2, index=[1,2,3,4]).drop([2,3,4])
# Out:
#     Ohio  Massachusetts  California  Texas
# 1  17000           3200       12500  12003

# %%
pd.DataFrame(data2, index=[0]).T
# Out:
#                    0
# Ohio           17000
# Massachusetts   3200
# California     12500
# Texas          12003

# %%
states = pd.DataFrame(data2, index=[0]).T

# %%
states.index.name = 'States'

# %%
states = states.reset_index()

# %%
states.rename(columns={0:'Population'})
# Out:
#           States  Population
# 0           Ohio       17000
# 1  Massachusetts        3200
# 2     California       12500
# 3          Texas       12003

# %%
states = states.rename(columns={0:'Population'})

# %%
states['Active'] = ['Yes','Yes','No','Yes']

# %%
pd.DataFrame(states)
# Out:
#           States  Population Active
# 0           Ohio       17000    Yes
# 1  Massachusetts        3200    Yes
# 2     California       12500     No
# 3          Texas       12003    Yes

# %%
states1 = {'Colorado':[30200,'No'],'Hawaii':[1100,'Yes'],'Vermont':[6450,'No']}

# %%
states1 = pd.DataFrame(states1).T.reset_index()

# %%
states1.rename(columns={'index':'States',0:'Population',1:'Active'})
# Out:
#      States Population Active
# 0  Colorado      30200     No
# 1    Hawaii       1100    Yes
# 2   Vermont       6450     No

# %%
states1 = states1.rename(columns={'index':'States',0:'Population',1:'Active'})

# %%
pd.concat([states,states1],axis=0)
# Out:
#           States Population Active
# 0           Ohio      17000    Yes
# 1  Massachusetts       3200    Yes
# 2     California      12500     No
# 3          Texas      12003    Yes
# 0       Colorado      30200     No
# 1         Hawaii       1100    Yes
# 2        Vermont       6450     No

# %%
new_states = pd.concat([states,states1],axis=0)

# %%
new_states.reset_index(drop=True,inplace=True)

# %%
new_states
# Out:
#           States Population Active
# 0           Ohio      17000    Yes
# 1  Massachusetts       3200    Yes
# 2     California      12500     No
# 3          Texas      12003    Yes
# 4       Colorado      30200     No
# 5         Hawaii       1100    Yes
# 6        Vermont       6450     No

# %%
new_states.drop([3])
# Out:
#           States Population Active
# 0           Ohio      17000    Yes
# 1  Massachusetts       3200    Yes
# 2     California      12500     No
# 4       Colorado      30200     No
# 5         Hawaii       1100    Yes
# 6        Vermont       6450     No

# %%
new_states.drop(['Active'],axis=1)
# Out:
#           States Population
# 0           Ohio      17000
# 1  Massachusetts       3200
# 2     California      12500
# 3          Texas      12003
# 4       Colorado      30200
# 5         Hawaii       1100
# 6        Vermont       6450

# %%
new_states['Rep'] = pd.DataFrame(['John','Carol','Jimmy','AJ','Kaylee','Brett','Dan'],index=[0,1,2,3,4,5,6])

# %%
new_states
# Out:
#           States Population Active     Rep
# 0           Ohio      17000    Yes    John
# 1  Massachusetts       3200    Yes   Carol
# 2     California      12500     No   Jimmy
# 3          Texas      12003    Yes      AJ
# 4       Colorado      30200     No  Kaylee
# 5         Hawaii       1100    Yes   Brett
# 6        Vermont       6450     No     Dan

# %%
new_states['Hiking?'] = pd.DataFrame(['No','Yes','Yes','No','Yes','Yes','Yes'])

# %%
new_states
# Out:
#           States Population Active     Rep Hiking?
# 0           Ohio      17000    Yes    John      No
# 1  Massachusetts       3200    Yes   Carol     Yes
# 2     California      12500     No   Jimmy     Yes
# 3          Texas      12003    Yes      AJ      No
# 4       Colorado      30200     No  Kaylee     Yes
# 5         Hawaii       1100    Yes   Brett     Yes
# 6        Vermont       6450     No     Dan     Yes

# %%
new_states['Music Scene Rank'] = pd.Series(['3','8','5'],index=[0,2,5])

# %%
new_states
# Out:
#           States Population Active     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    Yes    John      No                3
# 1  Massachusetts       3200    Yes   Carol     Yes              NaN
# 2     California      12500     No   Jimmy     Yes                8
# 3          Texas      12003    Yes      AJ      No              NaN
# 4       Colorado      30200     No  Kaylee     Yes              NaN
# 5         Hawaii       1100    Yes   Brett     Yes                5
# 6        Vermont       6450     No     Dan     Yes              NaN

# %%
new_states['Music Scene Rank'].ffill()
# Out:
# 0    3
# 1    3
# 2    8
# 3    8
# 4    8
# 5    5
# 6    5
# Name: Music Scene Rank, dtype: object

# %%
new_states['Music Scene Rank'].ffill(inplace=True)

# %%
new_states
# Out:
#           States Population Active     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    Yes    John      No                3
# 1  Massachusetts       3200    Yes   Carol     Yes                3
# 2     California      12500     No   Jimmy     Yes                8
# 3          Texas      12003    Yes      AJ      No                8
# 4       Colorado      30200     No  Kaylee     Yes                8
# 5         Hawaii       1100    Yes   Brett     Yes                5
# 6        Vermont       6450     No     Dan     Yes                5

# %%
new_states.drop(3).reset_index(drop=True)
# Out:
#           States Population Active     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    Yes    John      No                3
# 1  Massachusetts       3200    Yes   Carol     Yes                3
# 2     California      12500     No   Jimmy     Yes                8
# 3       Colorado      30200     No  Kaylee     Yes                8
# 4         Hawaii       1100    Yes   Brett     Yes                5
# 5        Vermont       6450     No     Dan     Yes                5

# %%
new_states
# Out:
#           States Population Active     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    Yes    John      No                3
# 1  Massachusetts       3200    Yes   Carol     Yes                3
# 2     California      12500     No   Jimmy     Yes                8
# 3          Texas      12003    Yes      AJ      No                8
# 4       Colorado      30200     No  Kaylee     Yes                8
# 5         Hawaii       1100    Yes   Brett     Yes                5
# 6        Vermont       6450     No     Dan     Yes                5

# %%
new_states.drop(['Active'],axis=1)
# Out:
#           States Population     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    John      No                3
# 1  Massachusetts       3200   Carol     Yes                3
# 2     California      12500   Jimmy     Yes                8
# 3          Texas      12003      AJ      No                8
# 4       Colorado      30200  Kaylee     Yes                8
# 5         Hawaii       1100   Brett     Yes                5
# 6        Vermont       6450     Dan     Yes                5

# %%
new_states.drop(columns=['Active'])
# Out:
#           States Population     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    John      No                3
# 1  Massachusetts       3200   Carol     Yes                3
# 2     California      12500   Jimmy     Yes                8
# 3          Texas      12003      AJ      No                8
# 4       Colorado      30200  Kaylee     Yes                8
# 5         Hawaii       1100   Brett     Yes                5
# 6        Vermont       6450     Dan     Yes                5

# %%
new_states.drop(5)
# Out:
#           States Population Active     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    Yes    John      No                3
# 1  Massachusetts       3200    Yes   Carol     Yes                3
# 2     California      12500     No   Jimmy     Yes                8
# 3          Texas      12003    Yes      AJ      No                8
# 4       Colorado      30200     No  Kaylee     Yes                8
# 6        Vermont       6450     No     Dan     Yes                5

# %%
new_states.drop(5).reset_index(drop=True)
# Out:
#           States Population Active     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    Yes    John      No                3
# 1  Massachusetts       3200    Yes   Carol     Yes                3
# 2     California      12500     No   Jimmy     Yes                8
# 3          Texas      12003    Yes      AJ      No                8
# 4       Colorado      30200     No  Kaylee     Yes                8
# 5        Vermont       6450     No     Dan     Yes                5

# %%
new_states[new_states['Music Scene Rank']>'5']
# Out:
#        States Population Active     Rep Hiking? Music Scene Rank
# 2  California      12500     No   Jimmy     Yes                8
# 3       Texas      12003    Yes      AJ      No                8
# 4    Colorado      30200     No  Kaylee     Yes                8

# %%
new_states.loc[4:]  #loc for the indexes and column names
# Out:
#      States Population Active     Rep Hiking? Music Scene Rank
# 4  Colorado      30200     No  Kaylee     Yes                8
# 5    Hawaii       1100    Yes   Brett     Yes                5
# 6   Vermont       6450     No     Dan     Yes                5

# %%
new_states.loc[4:,['Population','Active']] #loc for the indexes and column names
# Out:
#   Population Active
# 4      30200     No
# 5       1100    Yes
# 6       6450     No

# %%
new_states
# Out:
#           States Population Active     Rep Hiking? Music Scene Rank
# 0           Ohio      17000    Yes    John      No                3
# 1  Massachusetts       3200    Yes   Carol     Yes                3
# 2     California      12500     No   Jimmy     Yes                8
# 3          Texas      12003    Yes      AJ      No                8
# 4       Colorado      30200     No  Kaylee     Yes                8
# 5         Hawaii       1100    Yes   Brett     Yes                5
# 6        Vermont       6450     No     Dan     Yes                5

# %%
new_states.loc[:3,['States','Active','Rep','Music Scene Rank']]
# Out:
#           States Active    Rep Music Scene Rank
# 0           Ohio    Yes   John                3
# 1  Massachusetts    Yes  Carol                3
# 2     California     No  Jimmy                8
# 3          Texas    Yes     AJ                8

# %%
new_states.iloc[:3,[0,2,3,5]]   # iloc just for numbers
                                # same selection
# Out:
#           States Active    Rep Music Scene Rank
# 0           Ohio    Yes   John                3
# 1  Massachusetts    Yes  Carol                3
# 2     California     No  Jimmy                8

# %%
new_states.iloc[[2,3],[0,2,3,5]]  #subsections of both axes
# Out:
#        States Active    Rep Music Scene Rank
# 2  California     No  Jimmy                8
# 3       Texas    Yes     AJ                8

# %%
new_states.iloc[:,:3][new_states['Population'] > 15000]
# Out:
#      States Population Active
# 0      Ohio      17000    Yes
# 4  Colorado      30200     No

# %%
new_states['Profits'] = ['12000','123102','10000','166000','85000','72000','1120000']

# %%
new_states
# Out:
#           States Population Active     Rep Hiking? Music Scene Rank  Profits
# 0           Ohio      17000    Yes    John      No                3    12000
# 1  Massachusetts       3200    Yes   Carol     Yes                3   123102
# 2     California      12500     No   Jimmy     Yes                8    10000
# 3          Texas      12003    Yes      AJ      No                8   166000
# 4       Colorado      30200     No  Kaylee     Yes                8    85000
# 5         Hawaii       1100    Yes   Brett     Yes                5    72000
# 6        Vermont       6450     No     Dan     Yes                5  1120000

# %%
columns = ['Ticker','Date','Buy Price','Sell Price','Profit']

# %%
data = [1,2,3,4,5]

# %%
data_names = np.array(data)

# %%
stocks = pd.DataFrame(data_names.reshape(-1,len(data)), columns = columns)

# %%
stocks = ({columns})
# Out:
#    Ticker  Date  Buy Price  Sell Price  Profit
# 0       1     2          3           4       5

# %%
stocks = ({'AMZN':'12/01/2019','CPRT':'05/02/2019','NFLX':'02/14/2020','NVDA':'04/26/2020'})

# %%
pd.Series(stocks)
# Out:
# AMZN    12/01/2019
# CPRT    05/02/2019
# NFLX    02/14/2020
# NVDA    04/26/2020
# dtype: object

# %%
new_stocks = pd.DataFrame(pd.Series(stocks)).reset_index()

# %%
new_stocks
# Out:
#   index           0
# 0  AMZN  12/01/2019
# 1  CPRT  05/02/2019
# 2  NFLX  02/14/2020
# 3  NVDA  04/26/2020

# %%
columns = ['Ticker','Buy Date']

# %%
new_stocks.index.name = 'Trade'

# %%
new_stocks
# Out:
#       index           0
# Trade
# 0      AMZN  12/01/2019
# 1      CPRT  05/02/2019
# 2      NFLX  02/14/2020
# 3      NVDA  04/26/2020

# %%
new_stocks.reset_index()
# Out:
#    Trade index           0
# 0      0  AMZN  12/01/2019
# 1      1  CPRT  05/02/2019
# 2      2  NFLX  02/14/2020
# 3      3  NVDA  04/26/2020

# %%
new_stocks = new_stocks.rename(columns = {'index':'Ticker',0:'Buy Date'}).reset_index()

# %%
new_stocks
# Out:
#    Trade Ticker    Buy Date
# 0      0   AMZN  12/01/2019
# 1      1   CPRT  05/02/2019
# 2      2   NFLX  02/14/2020
# 3      3   NVDA  04/26/2020

# %%
new_stocks['Trade'] = [1,2,3,4]

# %%
new_stocks
# Out:
#    Trade Ticker    Buy Date
# 0      1   AMZN  12/01/2019
# 1      2   CPRT  05/02/2019
# 2      3   NFLX  02/14/2020
# 3      4   NVDA  04/26/2020

# %%
buy_data = ({'AMZN': 1500, 'CPRT':74, 'NFLX':174, 'NVDA':302})

# %%
pd.Series(buy_data)
# Out:
# AMZN    1500
# CPRT      74
# NFLX     174
# NVDA     302
# dtype: int64

# %%
buy_data = pd.DataFrame(pd.Series(buy_data)).rename(columns = {0:'Buy Price'}).reset_index()

# %%
buy_data.rename(columns = {'index':'Ticker'})
# Out:
#   Ticker  Buy Price
# 0   AMZN       1500
# 1   CPRT         74
# 2   NFLX        174
# 3   NVDA        302

# %%
old_data = pd.concat([new_stocks,buy_data],axis=1).drop(['index'],axis=1)

# %%
other_info = (['2674','43000','Success'],
              ['89','75392','Success'],
              ['162','-23200','Failure'],
              ['350','5632','Success'])

# %%
new_data = pd.DataFrame(other_info,columns = ['Sell Price','Profit','Status'])

# %%
pd.concat([old_data,new_data],axis=1)
# Out:
#    Trade Ticker    Buy Date  Buy Price Sell Price  Profit   Status
# 0      1   AMZN  12/01/2019       1500       2674   43000  Success
# 1      2   CPRT  05/02/2019         74         89   75392  Success
# 2      3   NFLX  02/14/2020        174        162  -23200  Failure
# 3      4   NVDA  04/26/2020        302        350    5632  Success

# %%
complete= pd.concat([old_data,new_data],axis=1)

# %%
last_minute = (['5','RGEN','04/27/2020','114','120','3200','Success'])

# %%
last_minute = pd.DataFrame(last_minute).T.rename(columns={0:'Trade',1:'Ticker',2:'Buy Date',3:'Buy Price',4:'Sell Price',5:'Profit',6:'Status'})

# %%
pd.concat([complete,last_minute],axis=0)
# Out:
#   Trade Ticker    Buy Date Buy Price Sell Price  Profit   Status
# 0     1   AMZN  12/01/2019      1500       2674   43000  Success
# 1     2   CPRT  05/02/2019        74         89   75392  Success
# 2     3   NFLX  02/14/2020       174        162  -23200  Failure
# 3     4   NVDA  04/26/2020       302        350    5632  Success
# 0     5   RGEN  04/27/2020       114        120    3200  Success

# %%
final_stocks = pd.concat([complete,last_minute],axis=0)

# %%
final_stocks.sort_values(by=['Buy Price','Profit'])
# Out:
#   Trade Ticker    Buy Date Buy Price Sell Price  Profit   Status
# 1     2   CPRT  05/02/2019        74         89   75392  Success
# 2     3   NFLX  02/14/2020       174        162  -23200  Failure
# 3     4   NVDA  04/26/2020       302        350    5632  Success
# 0     1   AMZN  12/01/2019      1500       2674   43000  Success
# 0     5   RGEN  04/27/2020       114        120    3200  Success

# %%
final_stocks.sort_values(by='Profit')
# Out:
#   Trade Ticker    Buy Date Buy Price Sell Price  Profit   Status
# 2     3   NFLX  02/14/2020       174        162  -23200  Failure
# 0     5   RGEN  04/27/2020       114        120    3200  Success
# 0     1   AMZN  12/01/2019      1500       2674   43000  Success
# 3     4   NVDA  04/26/2020       302        350    5632  Success
# 1     2   CPRT  05/02/2019        74         89   75392  Success

# %%
frame = pd.DataFrame(np.random.randn(4,3),columns=list('bde'),
                    index=['Utah','Ohio','Texas','Oregon'])

# %%
frame
# Out:
#                b         d         e
# Utah   -0.575021  0.155965 -0.087891
# Ohio    2.151064  0.485221  0.635742
# Texas  -0.458546 -0.052596  0.426963
# Oregon  1.340906  0.323939  0.836479

# %%
f = lambda x: x.max() - x.min()

# %%
frame.apply(f)
# Out:
# b    2.726084
# d    0.537817
# e    0.924370
# dtype: float64

# %%
frame.apply(f,axis='columns')
# Out:
#              min       max
# Utah   -0.575021  0.155965
# Ohio    0.485221  2.151064
# Texas  -0.458546  0.426963
# Oregon  0.323939  1.340906

# %%
def f(x):
    return pd.Series([x.min(), x.max()], index=['min','max'])

# %%
frame.apply(f)
# Out:
#             b         d         e
# min -0.575021 -0.052596 -0.087891
# max  2.151064  0.485221  0.836479

# %%
format= lambda x: '%.2f' % x

# %%
frame.applymap(format)
# Out:
#             b      d      e
# Utah    -0.58   0.16  -0.09
# Ohio     2.15   0.49   0.64
# Texas   -0.46  -0.05   0.43
# Oregon   1.34   0.32   0.84

# %%
final_stocks
# Out:
#   Trade Ticker    Buy Date Buy Price Sell Price  Profit   Status
# 0     1   AMZN  12/01/2019      1500       2674   43000  Success
# 1     2   CPRT  05/02/2019        74         89   75392  Success
# 2     3   NFLX  02/14/2020       174        162  -23200  Failure
# 3     4   NVDA  04/26/2020       302        350    5632  Success
# 0     5   RGEN  04/27/2020       114        120    3200  Success

# %%
make_integer = final_stocks.columns[3:6]

# %%
make_integer
# Out:
# Index(['Buy Price', 'Sell Price', 'Profit'], dtype='object')

# %%
final_stocks[make_integer] = final_stocks[make_integer].astype(int)

# %%
final_stocks
# Out:
#   Trade Ticker    Buy Date  Buy Price  Sell Price  Profit   Status
# 0     1   AMZN  12/01/2019       1500        2674   43000  Success
# 1     2   CPRT  05/02/2019         74          89   75392  Success
# 2     3   NFLX  02/14/2020        174         162  -23200  Failure
# 3     4   NVDA  04/26/2020        302         350    5632  Success
# 0     5   RGEN  04/27/2020        114         120    3200  Success

# %%
final_stocks['Price Gain/Loss'] = final_stocks['Sell Price'] - final_stocks['Buy Price']

# %%
final_stocks
# Out:
#   Trade Ticker    Buy Date  Buy Price  Sell Price  Profit   Status  \
# 0     1   AMZN  12/01/2019       1500        2674   43000  Success
# 1     2   CPRT  05/02/2019         74          89   75392  Success
# 2     3   NFLX  02/14/2020        174         162  -23200  Failure
# 3     4   NVDA  04/26/2020        302         350    5632  Success
# 0     5   RGEN  04/27/2020        114         120    3200  Success
#
#    Price Gain/Loss
# 0             1174
# 1               15
# 2              -12
# 3               48
# 0                6
